# %%
import numpy as np
import matplotlib.pyplot as plt

f = open('fib41_result.txt', 'r')

datalist = f.readlines()

fib_X = []
fib_Y1 = []
fib_Y2 = []
fib_Comp = []

for data in datalist:
    x,y1,y2,l1,l2=map(float,data.split())
    if x > 1000000:
        continue
#     if y2 > 30000000:
#         continue
    if y1 > 10000:
        print(x,y1,y2,l1,l2)
    if y1 > 10000:
        continue
    fib_X.append(x)
    fib_Y1.append(y1)
    fib_Y2.append(y2)
    fib_Comp.append(l1)

f.close()

fib_X = np.array(fib_X)
fib_Y1 = np.array(fib_Y1)
fib_Y2 = np.array(fib_Y2)
fib_Comp = np.array(fib_Comp)

f = open('rs.13_result.txt', 'r')

datalist = f.readlines()

rs_X = []
rs_Y1 = []
rs_Y2 = []

for data in datalist:
    x,y1,y2,l1,l2=map(float,data.split())
    if x > 1000000:
        continue
    if y1 > 10000:
        continue
    rs_X.append(x)
    rs_Y1.append(y1)
    rs_Y2.append(y2)

f.close()

rs_X = np.array(rs_X)
rs_Y1 = np.array(rs_Y1)
rs_Y2 = np.array(rs_Y2)

f = open('tm29_result.txt', 'r')

datalist = f.readlines()

tm29_X = []
tm29_Y1 = []
tm29_Y2 = []

for data in datalist:
    x,y1,y2,l1,l2=map(float,data.split())
    if x > 1000000:
        continue
    if y1 > 10000:
        continue
    tm29_X.append(x)
    tm29_Y1.append(y1)
    tm29_Y2.append(y2)

f.close()

tm29_X = np.array(tm29_X)
tm29_Y1 = np.array(tm29_Y1)
tm29_Y2 = np.array(tm29_Y2)
# Out:
# 3622.0 10446.7 138840.0 62.6 3506.13
# 8158.0 16100.0 292000.0 68.5 5439.33
# 8860.0 11175.0 400800.0 66.25 7088.8
# 11986.0 11533.3 409900.0 70.0 8990.25
# 12072.0 15975.0 435875.0 74.0 9658.4
# 12868.0 13120.0 440580.0 69.8 10724.2
# 22936.0 23125.0 785975.0 74.25 18349.6
# 42648.0 14100.0 1677400.0 81.0 21324.5
# 43225.0 12700.0 1528800.0 89.0 21613.0
# 67725.0 24000.0 2346000.0 87.0 33863.0
# 125315.0 11900.0 4376300.0 88.0 62658.0
# 403209.0 31700.0 14155300.0 99.0 201605.0

# %%
p1 = plt.plot(fib_X,fib_Y1,linewidth = 1)

plt.grid(False)
plt.title('Algorithm 1')
plt.xlabel("lngth of LCE")
plt.ylabel("time [ns]")

plt.savefig('fib1.png')

# %%
p1 = plt.plot(fib_X,fib_Y1)
plt.plot(fib_X,fib_Y2)
plt.grid(False)
plt.title('Algorithm 2')
plt.xlabel("length of LCE")
plt.ylabel("time [ns]")
plt.legend((p1[0],p2[0]),("Algo1","Algo2"),loc = 2)
plt.savefig('fib2.png')

# %%
plt.plot(rs_X,rs_Y1)
plt.title('Algorithm 1')
plt.xlabel("Length of LCE")
plt.ylabel("time [ns]")
# Out:
# Text(0, 0.5, 'time [ns]')

# %%
plt.plot(rs_X,rs_Y1)
plt.plot(rs_X,rs_Y2)
plt.xlabel("Length of LCE")
plt.title('Algorithm 2')
plt.ylabel("time [ns]")
plt.legend((p1[0],p2[0]),("Algo1","Algo2"),loc = 2)

# %%
plt.plot(tm29_X,tm29_Y1,marker="o",markersize=2)
plt.xlabel("Length of LCE")
plt.title('Algorithm 1')
plt.ylabel("time [ns]")
# Out:
# Text(0, 0.5, 'time [ns]')

# %%
plt.plot(tm29_X,tm29_Y1)
plt.plot(tm29_X,tm29_Y2)
plt.xlabel("Length of LCE")
plt.title('Algorithm 2')
plt.ylabel("time [ns]")
plt.legend((p1[0],p2[0]),("Algo1","Algo2"),loc = 2)

# %%
f = open('proteins_result.txt','r')

datalist = f.readlines()

p_X = []
p_Y1 = []
p_Y2 = []

for data in datalist:
    x, y1, y2,l1,l2 = map(float,data.split())
    if x > 2000:
        continue
    if y1 > 10000:
        continue
    p_X.append(x)
    p_Y1.append(y1)
    p_Y2.append(y2)
    
f.close()

p_X = np.array(p_X)
p_Y1 = np.array(p_Y1)
p_Y2 = np.array(p_Y2)

# %%
plt.plot(p_X,p_Y1)
plt.title('Algorithm1')
plt.xlabel("Length of LCE")
plt.ylabel("time [ns]")
# Out:
# Text(0, 0.5, 'time [ns]')

# %%
p1 = plt.plot(p_X,p_Y1)
p2 = plt.plot(p_X,p_Y2)
plt.xlabel("Length of LCE")
plt.ylabel("time [ns]")
plt.legend((p1[0],p2[0]),("Algo1","Algo2"),loc = 2)

# %%
f = open('sources_result.txt' ,'r')

datalist = f.readlines()

s_X = []
s_Y1 = []
s_Y2 = []

for data in datalist:
    x, y1, y2,l1,l2 = map(float,data.split())
    if x > 800:
        continue
    s_X.append(x)
    s_Y1.append(y1)
    s_Y2.append(y2)
    
f.close()

s_X = np.array(s_X)
s_Y1 = np.array(s_Y1)
s_Y2 = np.array(s_Y2)

# %%
plt.plot(s_X,s_Y1)
plt.xlabel("Length of LCE")
plt.ylabel("time [ns]")
# Out:
# Text(0, 0.5, 'time [ns]')

# %%
p1 = plt.plot(s_X,s_Y1)
p2 = plt.plot(s_X,s_Y2)
plt.xlabel("Length of LCE")
plt.ylabel("time [ns]")
plt.legend((p1[0],p2[0]),("Algo1","Algo2"),loc = 2)
